# %% [markdown]
# <a href="https://colab.research.google.com/github/zuzanadostalova/Census-Dataset/blob/main/Census_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.where(df['SUMLEV'] == 50).dropna().set_index(['SUMLEV', 'CTYNAME'])
# Out:
#                           REGION  DIVISION  STATE  COUNTY   STNAME  \
# SUMLEV CTYNAME
# 50.0   Autauga County        3.0       6.0    1.0     1.0  Alabama
#        Baldwin County        3.0       6.0    1.0     3.0  Alabama
#        Barbour County        3.0       6.0    1.0     5.0  Alabama
#        Bibb County           3.0       6.0    1.0     7.0  Alabama
#        Blount County         3.0       6.0    1.0     9.0  Alabama
# ...                          ...       ...    ...     ...      ...
#        Sweetwater County     4.0       8.0   56.0    37.0  Wyoming
#        Teton County          4.0       8.0   56.0    39.0  Wyoming
#        Uinta County          4.0       8.0   56.0    41.0  Wyoming
#        Washakie County       4.0       8.0   56.0    43.0  Wyoming
#        Weston County         4.0       8.0   56.0    45.0  Wyoming
#
#                           CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# SUMLEV CTYNAME
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 
                'POPESTIMATE2014', 'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})
df.apply(min_max, axis=1)
# Out:
#           min      max
# 0     4785161  4858979
# 1       54660    55347
# 2      183193   203709
# 3       26489    27341
# 4       22512    22861
# ...       ...      ...
# 3188    43593    45162
# 3189    21297    23125
# 3190    20822    21102
# 3191     8316     8545
# 3192     7065     7234
#
# [3193 rows x 2 columns]

# %%
df=df[df['SUMLEV'] == 50]
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME'] == state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df = df.set_index('STNAME')
df
# Out:
#          SUMLEV  REGION  DIVISION  STATE  COUNTY            CTYNAME  \
# STNAME
# Alabama      40       3         6      1       0            Alabama
# Alabama      50       3         6      1       1     Autauga County
# Alabama      50       3         6      1       3     Baldwin County
# Alabama      50       3         6      1       5     Barbour County
# Alabama      50       3         6      1       7        Bibb County
# ...         ...     ...       ...    ...     ...                ...
# Wyoming      50       4         8     56      37  Sweetwater County
# Wyoming      50       4         8     56      39       Teton County
# Wyoming      50       4         8     56      41       Uinta County
# Wyoming      50       4         8     56      43    Washakie County
# Wyoming      50       4         8     56      45      Weston County
#
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# ...

# %%
def fun(item):
    if item[0] < 'M':
        return 0
    if item[0] < 'Q':
        return 1
    return 2
for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group' + str(group) + ' for processing.')
# Out:
# There are 1196 records in group0 for processing.
# There are 1154 records in group1 for processing.
# There are 843 records in group2 for processing.

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df = df[df['SUMLEV'] == 50]
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print (type(df.groupby(level = 0)['POPESTIMATE2010', 'POPESTIMATE2011']))
print (type(df.groupby(level = 0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
(df.set_index('STNAME').groupby('STNAME')['CENSUS2010POP']
   .agg([('avg', np.average), ('sum', np.sum)]))
# Out:
#                                 avg       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# Idaho                  35626.863636   1567582
# Illinois              125790.509804  12830632
# Indiana                70476.108696   6483802
# Iowa                   30771.262626   3046355
# Kansas                 27172.552381   2853118
# Kentucky               36161.391667   4339367
# Louisiana              70833.937500   4533372
# ...

# %%
(df.set_index('STNAME').groupby('STNAME')['CENSUS2010POP', 'POPESTIMATE2011']
   .agg([('avg', np.average), ('sum', np.sum)]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                       CENSUS2010POP           POPESTIMATE2011
#                                 avg       sum             avg       sum
# STNAME
# Alabama                71339.343284   4779736    71658.328358   4801108
# Alaska                 24490.724138    710231    24921.379310    722720
# Arizona               426134.466667   6392017   431248.800000   6468732
# Arkansas               38878.906667   2915918    39180.506667   2938538
# California            642309.586207  37253956   650000.586207  37700034
# Colorado               78581.187500   5029196    79991.875000   5119480
# Connecticut           446762.125000   3574097   448719.875000   3589759
# Delaware              299311.333333    897934   302638.666667    907916
# ...

# %%
(df.set_index('STNAME').groupby('STNAME')['POPESTIMATE2010', 'POPESTIMATE2011']
   .agg([('POPESTIMATE2010', np.average), ('POPESTIMATE2011', np.sum)]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      POPESTIMATE2010                 POPESTIMATE2011  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 71420.313433         4785161    71658.328358
# Alaska                  24621.413793          714021    24921.379310
# Arizona                427213.866667         6408208   431248.800000
# Arkansas                38965.253333         2922394    39180.506667
# California             643691.017241        37334079   650000.586207
# Colorado                78878.968750         5048254    79991.875000
# Connecticut            447464.625000         3579717   448719.875000
# Delaware               299930.333333          899791   302638.666667
# ...

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df
# Out:
#             0
# excellent  A+
# excellent   A
# excellent  A-
# good       B+
# good        B
# good       B-
# ok         C+
# ok          C
# ok         C-
# poor       D+
# poor        D

# %%
df.rename(columns={0: 'Grades'}, inplace = True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype



df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
grades = df['Grades'].astype(CategoricalDtype(categories = ['D','D+', 
                                                       'C-', 'C', 'C+',
                                                       'B-', 'B', 'B+',
                                                       'A-', 'A', 'A+'],
                                                      ordered=True))
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %%
grades>'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df = df[df['SUMLEV'] == 50]
df.set_index('STNAME').groupby(level=0).agg({"CENSUS2010POP": [np.average]})
# Out:
#                       CENSUS2010POP
#                             average
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# ...

# %%
pd.cut(df['average'], 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'average'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
s = pd.Series([168, 180, 179, 190, 200, 225, 160, 120, 150, 145, 165, 123, 180, 165, 177, 138, 145, 129, 135])
pd.cut(s, 5)
# Out:
# 0       (162.0, 183.0]
# 1       (162.0, 183.0]
# 2       (162.0, 183.0]
# 3       (183.0, 204.0]
# 4       (183.0, 204.0]
# 5       (204.0, 225.0]
# 6       (141.0, 162.0]
# 7     (119.895, 141.0]
# 8       (141.0, 162.0]
# 9       (141.0, 162.0]
# 10      (162.0, 183.0]
# 11    (119.895, 141.0]
# 12      (162.0, 183.0]
# 13      (162.0, 183.0]
# 14      (162.0, 183.0]
# 15    (119.895, 141.0]
# 16      (141.0, 162.0]
# 17    (119.895, 141.0]
# 18    (119.895, 141.0]
# dtype: category
# Categories (5, interval[float64, right]): [(119.895, 141.0] < (141.0, 162.0] < (162.0, 183.0] <
#                                            (183.0, 204.0] < (204.0, 225.0]]

# %%
pd.cut(s,3, labels=['small', 'medium', 'large'])
# Out:
# 0     medium
# 1     medium
# 2     medium
# 3     medium
# 4      large
# 5      large
# 6     medium
# 7      small
# 8      small
# 9      small
# 10    medium
# 11     small
# 12    medium
# 13    medium
# 14    medium
# 15     small
# 16     small
# 17     small
# 18     small
# dtype: category
# Categories (3, object): ['small' < 'medium' < 'large']

# %%
pd.Timestamp('9/1/2016 10.05AM')
# Out:
# Timestamp('2016-09-01 10:00:00')

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-9-03')])

# %%
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
t2 = pd.Series(list('efg'), [pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])

# %%
t2
# Out:
# 2016-09    e
# 2016-10    f
# 2016-11    g
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index = d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   37  37
# Aug 29, 2014  32  15
# 2015-06-26    16  49
# 7/12/16       21  55

# %%
ts3.index = pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#              a   b
# 2013-06-02  37  37
# 2014-08-29  32  15
# 2015-06-26  16  49
# 2016-07-12  21  55

# %%
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %%
pd.Timestamp('9/3/2016') - pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/3/2016') + pd.Timedelta('12D3H')
# Out:
# Timestamp('2016-09-15 03:00:00')

# %%
dates = pd.date_range('10-10-2016', periods = 9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-16', '2016-10-30', '2016-11-13', '2016-11-27',
#                '2016-12-11', '2016-12-25', '2017-01-08', '2017-01-22',
#                '2017-02-05'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
df = pd.DataFrame({'count1': 100+np.random.randint(-5,10,9).cumsum(), 
                   'count2': 120+np.random.randint(-5, 10, 9)}, index = dates)

# %%
df.index.day_name()
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday'],
#       dtype='object')

# %%
df.diff()
# Out:
#             count1  count2
# 2016-10-16     NaN     NaN
# 2016-10-30    -5.0     2.0
# 2016-11-13    -1.0     5.0
# 2016-11-27     1.0     2.0
# 2016-12-11     9.0    -4.0
# 2016-12-25     6.0     4.0
# 2017-01-08     9.0    -3.0
# 2017-01-22    -5.0    -1.0
# 2017-02-05     1.0     5.0

# %%
df.resample('M').mean()
# Out:
#             count1  count2
# 2016-10-31   101.5   119.0
# 2016-11-30    98.5   126.0
# 2016-12-31   111.0   125.0
# 2017-01-31   120.5   123.5
# 2017-02-28   119.0   128.0

# %%
df['2017']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#             count1  count2
# 2017-01-08     123     124
# 2017-01-22     118     123
# 2017-02-05     119     128

# %%
df['2016-12']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#             count1  count2
# 2016-12-11     108     123
# 2016-12-25     114     127

# %%
df.asfreq('W', method='ffill')
# Out:
#             count1  count2
# 2016-10-16     104     118
# 2016-10-23     104     118
# 2016-10-30      99     120
# 2016-11-06      99     120
# 2016-11-13      98     125
# 2016-11-20      98     125
# 2016-11-27      99     127
# 2016-12-04      99     127
# 2016-12-11     108     123
# 2016-12-18     108     123
# 2016-12-25     114     127
# 2017-01-01     114     127
# 2017-01-08     123     124
# 2017-01-15     123     124
# 2017-01-22     118     123
# 2017-01-29     118     123
# 2017-02-05     119     128

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot()
